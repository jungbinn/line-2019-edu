# %% [markdown]
# # Predicting sentiment from product reviews
#
# # Fire up GraphLab Create
# (See [Getting Started with SFrames](/notebooks/Week%201/Getting%20Started%20with%20SFrames.ipynb) for setup instructions)

# %%
import graphlab

# %%
# Limit number of worker processes. This preserves system memory, which prevents hosted notebooks from crashing.
graphlab.set_runtime_config('GRAPHLAB_DEFAULT_NUM_PYLAMBDA_WORKERS', 4)
# Out:
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: /tmp/graphlab_server_1547627975.log
# This non-commercial license of GraphLab Create for academic use is assigned to qlrqod55@gmail.com and will expire on January 16, 2020.

# %%
products = graphlab.SFrame('amazon_baby.gl/')

# %%
word_count = list(graphlab.text_analytics.count_words(products['review']))
# Out:
# [{'6': 1,
#   '8': 1,
#   'a': 2,
#   'about': 1,
#   'also': 1,
#   'and': 5,
#   'are': 3,
#   'because': 1,
#   'been': 1,
#   'blue-12': 1,
#   'boyfor': 1,
#   'but': 1,
#   'cloth': 2,
#   'countwhich': 1,
#   'fab': 1,
#   'faces': 1,
#   'flannel': 1,
#   'for': 2,
#   'get': 1,
#   'had': 2,
#   'handles.': 1,
#   'hands': 1,
#   'have': 2,
#   'higher': 1,
#   'i': 2,
#   'in': 1,
#   'issues': 1,
#   'just': 1,
#   'keeping.': 1,
#   'larger,': 1,
#   'longer': 1,
#   'months': 1,
#   'my': 1,
#   'need': 1,
#   'nicer,': 1,
#   'no': 1,
#   'not': 1,
#   'now': 1,
#   'ok,': 1,
#   'opinion': 1,
#   'ordered': 1,
#   'pack': 1,
#   'quality.': 1,
#   'replace': 1,
#   'rough': 1,
#   'seemed': 1,
#   'softer': 1,
#   'someimse': 1,
#   'starting': 1,
#   'stink': 1,
#   'stripping': 1,
#   'texture': 1,
#   'that': 1,
#   'them': 1,
#   'these': 1,
#   'they': 1,
#   'to': 2,
#   'use': 1,
#   'usingthirsties': 1,
#   'vimse': 1,
#   'while': 1,
#   'wipes': 2,
# ...

# %%
selected_words = ['awesome', 'great', 'fantastic', 'amazing', 'love', 'horrible', 'bad', 
                  'terrible', 'awful', 'wow', 'hate']

# %%
def count_words(dic):
    count = {}
    for w in selected_words:
        if 

for word in selected_words:
    for i in range(products.shape[0]):
        products[word, i] =
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-c2f6c3874fcd> in <module>()
#       2
#       3 for word in selected_words:
# ----> 4     products[word] = word_count.get(word)
#
# AttributeError: 'SArray' object has no attribute 'get'
